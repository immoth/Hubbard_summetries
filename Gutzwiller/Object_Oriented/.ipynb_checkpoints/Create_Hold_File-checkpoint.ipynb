# %%
#%%writefile Define_Hold_Function.py

from qiskit.circuit import Qubit, Instruction, QuantumRegister
import copy

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 

# Prints out a list of gate names in the order that they are applied
def print_circ(circ):
    import numpy as np
    Lc = len(circ_new.data)
    tst = []
    for i in range(Lc):
        angle = np.round(circ_new.data[i][0].params,3)
        idx = circ_new.data[i][1][0].index
        name = circ_new.data[i][0].name
        tst.append([i,name,idx,angle])
    return tst


# Creates an Cx rotation gate in the language of instructions so that it can be inserted into the instructions
def cx(q1,q2,circ):
    circ.cx(q1,q2)
    out = circ.data[-1]
    circ.data.pop(-1)
    return out

#Inserts a (Cx Cx)^level identity to hold the circuit for a period of time
def insert_cxcx(level,q1,q2,i,circ):
    for l in range(level):
        circ.data.insert(i+1+2*l,cx(q1,q2,circ))
        circ.data.insert(i+2+2*l,cx(q1,q2,circ))
    return 

#Creates a new circuit with CxCx^level inserted after every Cnot gate
def create_cxcx_circ(level,circ_in):
    circ = copy.deepcopy(circ_in)
    Lc = len(circ.data)
    i=0
    while i < Lc:
        idx = circ.data[i][1][0].index
        name = circ.data[i][0].name
        #print(i,name)
        #print(print_circ(circ))
        if name == 'cx':
            #print(i)
            q1 = circ.data[i][1][0].index
            q2 = circ.data[i][1][1].index
            insert_cxcx(level,q1,q2,i,circ)
            Lc += 2*level
            i += 2*level
        i += 1
    return circ

# Creates a CxCx circuit for each circuit in a list
def create_cxcx_circs(level,circs_in):
    out = []
    for circ_in in circs_in:
        out.append(create_cxcx_circ(level,circ_in))
    return out

# Creates an Ry rotation gate in the language of instructions so that it can be inserted into the instructions
def ry(angle,qbit,circ):
    circ.ry(angle,qbit)
    out = circ.data[-1]
    circ.data.pop(-1)
    return out

#Inserts a Ry(phi)Ry(-phi) identity to hold the circuit for a period of time
def insert_hold(angle,qbit,i,circ):
    reg_name = circ.data[0][1][0].register.name
    N = circ.data[0][1][0].register.size
    circ.data.insert(i+1,ry(angle,qbit,circ))
    circ.data.insert(i+2,ry(-angle,qbit,circ))
    return 


#Creates a new circuit with Ry(phi)Ry(-phi) inserted after every Cnot gate
def create_hold_circ(angle,circ_in):
    circ = copy.deepcopy(circ_in)
    Lc = len(circ.data)
    i=0
    while i < Lc:
        idx = circ.data[i][1][0].index
        name = circ.data[i][0].name
        #print(i,name)
        #print(print_circ(circ))
        if name == 'cx':
            qbit = circ.data[i][1][0].index
            insert_hold(angle,qbit,i,circ)
            Lc += 2
        i += 1
    return circ

# Creates a hold circuit for each circuit in a list
def create_hold_circs(angle,circs_in):
    out = []
    for circ_in in circs_in:
        out.append(create_hold_circ(angle,circ_in))
    return out

# %% [markdown]
# # Tests

# %%
from Define_System import system
from Define_Slater_Circuit import slater_circ
from Define_Measurment_Circuits import create_circs

# %%
systemQ = system('triangle',4) 
Fd = systemQ.Fld()
paulis = systemQ.pauli_strings()
circs = create_circs(Fd,paulis)

# %% [markdown]
# ### CxCx Circuits

# %%
circ_new = create_cxcx_circ(2,circs[0])
circs_new = create_cxcx_circs(3,circs)

circs_new[2].draw()
# Out:
#         ┌───────┐┌──────────┐                                               »
# q132_0: ┤ Rz(π) ├┤ Ry(-π/2) ├───────────────────────────────────────────────»
#         ├───────┤├──────────┤                                               »
# q132_1: ┤ Rz(0) ├┤ Ry(-π/2) ├───────────────────────────────────────────────»
#         └─┬───┬─┘└┬───────┬─┘┌──────────┐                                   »
# q132_2: ──┤ X ├───┤ Rz(0) ├──┤ Ry(-π/2) ├──■────■────■────■────■────■────■──»
#           ├───┤   ├───────┴┐ └──────────┘┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐»
# q132_3: ──┤ X ├───┤ Rz(-π) ├─────────────┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├»
#           └───┘   └────────┘             └───┘└───┘└───┘└───┘└───┘└───┘└───┘»
# c132: 4/════════════════════════════════════════════════════════════════════»
#                                                                             »
# «                                                                          »
# «q132_0: ──────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q132_1: ──────────────────────────────────────────────────────────────────»
# «                                                    ┌─────────┐ ┌───┐┌───┐»
# «q132_2: ───────────■────■────■────■────■────■────■──┤ Ry(π/2) ├─┤ X ├┤ X ├»
# «        ┌───────┐┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐├─────────┴┐└─┬─┘└─┬─┘»
# «q132_3: ┤ Ry(0) ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ Ry(-π/2) ├──■────■──»
# «        └───────┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└──────────┘          »
# «c132: 4/══════════════════════════════════════════════════════════════════»
# «                                                                          »
# «                                                                             »
# «q132_0: ─────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «q132_1: ─────────────────────────────────────────────────────────────────────»
# «        ┌───┐┌───┐┌───┐┌───┐┌───┐┌───────┐┌───┐┌───┐┌───┐┌───┐┌───┐┌───┐┌───┐»
# «q132_2: ┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ Ry(0) ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├»
# «        └─┬─┘└─┬─┘└─┬─┘└─┬─┘└─┬─┘└───────┘└─┬─┘└─┬─┘└─┬─┘└─┬─┘└─┬─┘└─┬─┘└─┬─┘»
# «q132_3: ──■────■────■────■────■─────────────■────■────■────■────■────■────■──»
# «                                                                             »
# «c132: 4/═════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «                                                                          »
# «q132_0: ──────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q132_1: ─────■─────────■──────■────■────■────■────■───────────────■────■──»
# «           ┌─┴─┐     ┌─┴─┐  ┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐┌─────────┐┌─┴─┐┌─┴─┐»
# «q132_2: ───┤ X ├─────┤ X ├──┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ Ry(π/2) ├┤ X ├┤ X ├»
# «        ┌──┴───┴──┐┌─┴───┴─┐└───┘└───┘└───┘└───┘└───┘└─────────┘└───┘└───┘»
# «q132_3: ┤ Ry(π/2) ├┤ Rz(π) ├──────────────────────────────────────────────»
# «        └─────────┘└───────┘                                              »
# «c132: 4/══════════════════════════════════════════════════════════════════»
# «                                                                          »
# «                                                                           »
# «q132_0: ───────────────────────────────────────────────────────────────────»
# «                                 ┌─────────┐ ┌───┐┌───┐┌───┐┌───┐┌───┐┌───┐»
# «q132_1: ──■────■────■────■────■──┤ Ry(π/2) ├─┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├»
# «        ┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐├─────────┴┐└─┬─┘└─┬─┘└─┬─┘└─┬─┘└─┬─┘└─┬─┘»
# «q132_2: ┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ Ry(-π/2) ├──■────■────■────■────■────■──»
# «        └───┘└───┘└───┘└───┘└───┘└──────────┘                              »
# «q132_3: ───────────────────────────────────────────────────────────────────»
# «                                                                           »
# «c132: 4/═══════════════════════════════════════════════════════════════════»
# «                                                                           »
# «                                                                       »
# «q132_0: ─────────────────────────────────────────────────────────■─────»
# «        ┌───┐┌──────────┐┌───┐┌───┐┌───┐┌───┐┌───┐┌───┐┌───┐   ┌─┴─┐   »
# «q132_1: ┤ X ├┤ Ry(-π/2) ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├───┤ X ├───»
# «        └─┬─┘└──────────┘└─┬─┘└─┬─┘└─┬─┘└─┬─┘└─┬─┘└─┬─┘└─┬─┘┌──┴───┴──┐»
# «q132_2: ──■────────────────■────■────■────■────■────■────■──┤ Ry(π/2) ├»
# «                                                            └─────────┘»
# «q132_3: ───────────────────────────────────────────────────────────────»
# «                                                                       »
# «c132: 4/═══════════════════════════════════════════════════════════════»
# «                                                                       »
# «                                                                      »
# «q132_0: ────■─────────■────────■────■────■────■───────────────■────■──»
# «          ┌─┴─┐     ┌─┴─┐    ┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐┌─────────┐┌─┴─┐┌─┴─┐»
# «q132_1: ──┤ X ├─────┤ X ├────┤ X ├┤ X ├┤ X ├┤ X ├┤ Ry(π/3) ├┤ X ├┤ X ├»
# «        ┌─┴───┴─┐┌──┴───┴───┐└───┘└───┘└───┘└───┘└─────────┘└───┘└───┘»
# «q132_2: ┤ Rz(π) ├┤ Ry(-π/2) ├──■────■────■────■───────■───────■────■──»
# «        └───────┘└──────────┘┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐   ┌─┴─┐   ┌─┴─┐┌─┴─┐»
# «q132_3: ─────────────────────┤ X ├┤ X ├┤ X ├┤ X ├───┤ X ├───┤ X ├┤ X ├»
# «                             └───┘└───┘└───┘└───┘   └───┘   └───┘└───┘»
# «c132: 4/══════════════════════════════════════════════════════════════»
# «                                                                      »
# «                                     ┌─────────┐ ┌───┐┌───┐   ┌───┐    ┌───┐»
# «q132_0: ────■──────■────■────■────■──┤ Ry(π/2) ├─┤ X ├┤ X ├───┤ X ├────┤ X ├»
# «          ┌─┴─┐  ┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐├─────────┴┐└─┬─┘└─┬─┘   └─┬─┘    └─┬─┘»
# «q132_1: ──┤ X ├──┤ X ├┤ X ├┤ X ├┤ X ├┤ Ry(-π/2) ├──■────■───────■────────■──»
# «          └───┘  └───┘└───┘└───┘└───┘└──────────┘          ┌─────────┐ ┌───┐»
# «q132_2: ───────────■────■────■────■───────■────────■────■──┤ Ry(π/2) ├─┤ X ├»
# «        ┌───────┐┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐   ┌─┴─┐    ┌─┴─┐┌─┴─┐├─────────┴┐└─┬─┘»
# «q132_3: ┤ Ry(0) ├┤ X ├┤ X ├┤ X ├┤ X ├───┤ X ├────┤ X ├┤ X ├┤ Ry(-π/2) ├──■──»
# «        └───────┘└───┘└───┘└───┘└───┘   └───┘    └───┘└───┘└──────────┘     »
# «c132: 4/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «        ┌───┐┌───┐┌───┐┌──────────┐┌───┐┌───┐  ┌───┐  ┌───┐┌───┐┌───┐┌───┐»
# «q132_0: ┤ X ├┤ X ├┤ X ├┤ Ry(-π/3) ├┤ X ├┤ X ├──┤ X ├──┤ X ├┤ X ├┤ X ├┤ X ├»
# «        └─┬─┘└─┬─┘└─┬─┘└──────────┘└─┬─┘└─┬─┘  └─┬─┘  └─┬─┘└─┬─┘└─┬─┘└─┬─┘»
# «q132_1: ──■────■────■────────────────■────■──────■──────■────■────■────■──»
# «        ┌───┐┌───┐┌───┐   ┌───┐    ┌───┐┌───┐┌───────┐┌───┐┌───┐┌───┐┌───┐»
# «q132_2: ┤ X ├┤ X ├┤ X ├───┤ X ├────┤ X ├┤ X ├┤ Ry(0) ├┤ X ├┤ X ├┤ X ├┤ X ├»
# «        └─┬─┘└─┬─┘└─┬─┘   └─┬─┘    └─┬─┘└─┬─┘└───────┘└─┬─┘└─┬─┘└─┬─┘└─┬─┘»
# «q132_3: ──■────■────■───────■────────■────■─────────────■────■────■────■──»
# «                                                                          »
# «c132: 4/══════════════════════════════════════════════════════════════════»
# «                                                                          »
# «        ┌──────────┐                                                        »
# «q132_0: ┤ Rz(-π/4) ├────────────────────────────────────────────────────────»
# «        ├─────────┬┘┌───────┐┌──────────┐                                   »
# «q132_1: ┤ Ry(π/2) ├─┤ Rz(0) ├┤ Ry(-π/2) ├─────■─────────■──────■────■────■──»
# «        └──┬───┬──┘ └─┬───┬─┘└──┬───┬───┘   ┌─┴─┐     ┌─┴─┐  ┌─┴─┐┌─┴─┐┌─┴─┐»
# «q132_2: ───┤ X ├──────┤ X ├─────┤ X ├───────┤ X ├─────┤ X ├──┤ X ├┤ X ├┤ X ├»
# «           └─┬─┘      └─┬─┘     └─┬─┘    ┌──┴───┴──┐┌─┴───┴─┐└───┘└───┘└───┘»
# «q132_3: ─────■──────────■─────────■──────┤ Ry(π/2) ├┤ Rz(0) ├───────────────»
# «                                         └─────────┘└───────┘               »
# «c132: 4/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «                                                                    »
# «q132_0: ────────────────────────────────────────────────────────────»
# «                                                                    »
# «q132_1: ──■────■───────────────────■────■────■────■────■────■────■──»
# «        ┌─┴─┐┌─┴─┐┌─────────────┐┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐»
# «q132_2: ┤ X ├┤ X ├┤ Ry(0.95532) ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├»
# «        └───┘└───┘└─────────────┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘»
# «q132_3: ────────────────────────────────────────────────────────────»
# «                                                                    »
# «c132: 4/════════════════════════════════════════════════════════════»
# «                                                                    »
# «                                                                            »
# «q132_0: ────────────────────────────────────────────────────────────────────»
# «        ┌─────────┐ ┌───┐┌───┐┌───┐┌───┐┌───┐┌───┐┌───┐┌──────────────┐┌───┐»
# «q132_1: ┤ Ry(π/2) ├─┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ Ry(-0.95532) ├┤ X ├»
# «        ├─────────┴┐└─┬─┘└─┬─┘└─┬─┘└─┬─┘└─┬─┘└─┬─┘└─┬─┘└──────────────┘└─┬─┘»
# «q132_2: ┤ Ry(-π/2) ├──■────■────■────■────■────■────■────────────────────■──»
# «        └──────────┘                                                        »
# «q132_3: ────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «c132: 4/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «                                                   ┌───┐     ┌───┐    ┌───┐»
# «q132_0: ───────────────────────────────────────────┤ X ├─────┤ X ├────┤ X ├»
# «        ┌───┐┌───┐┌───┐┌───┐┌───┐┌───┐┌─────────┐  └─┬─┘     └─┬─┘    └─┬─┘»
# «q132_1: ┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ Rz(π/4) ├────■─────────■────────■──»
# «        └─┬─┘└─┬─┘└─┬─┘└─┬─┘└─┬─┘└─┬─┘├─────────┤┌───────┐┌──────────┐     »
# «q132_2: ──■────■────■────■────■────■──┤ Ry(π/2) ├┤ Rz(0) ├┤ Ry(-π/2) ├──■──»
# «                                      └─────────┘└───────┘└──────────┘┌─┴─┐»
# «q132_3: ──────────────────────────────────────────────────────────────┤ X ├»
# «                                                                      └───┘»
# «c132: 4/═══════════════════════════════════════════════════════════════════»
# «                                                                           »
# «        ┌───┐┌───┐┌───┐┌───┐                                                »
# «q132_0: ┤ X ├┤ X ├┤ X ├┤ X ├───────────────────────────■───────■────■────■──»
# «        └─┬─┘└─┬─┘└─┬─┘└─┬─┘┌─────────┐┌─────────┐   ┌─┴─┐   ┌─┴─┐┌─┴─┐┌─┴─┐»
# «q132_1: ──■────■────■────■──┤ Ry(π/2) ├┤ Rz(π/8) ├───┤ X ├───┤ X ├┤ X ├┤ X ├»
# «                            └─────────┘└─────────┘   └───┘   └───┘└───┘└───┘»
# «q132_2: ──■────■────■────■───────■──────────■──────────────────■────■────■──»
# «        ┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐   ┌─┴─┐      ┌─┴─┐   ┌─────────┐┌─┴─┐┌─┴─┐┌─┴─┐»
# «q132_3: ┤ X ├┤ X ├┤ X ├┤ X ├───┤ X ├──────┤ X ├───┤ Ry(π/4) ├┤ X ├┤ X ├┤ X ├»
# «        └───┘└───┘└───┘└───┘   └───┘      └───┘   └─────────┘└───┘└───┘└───┘»
# «c132: 4/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «                                                                             »
# «q132_0: ──■────■────■───────────────────■────────■────■────■────■────■────■──»
# «        ┌─┴─┐┌─┴─┐┌─┴─┐┌──────────┐   ┌─┴─┐    ┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐»
# «q132_1: ┤ X ├┤ X ├┤ X ├┤ Rz(-π/4) ├───┤ X ├────┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├»
# «        └───┘└───┘└───┘└──────────┘┌──┴───┴──┐ ├───┤├───┤├───┤├───┤├───┤├───┤»
# «q132_2: ──■────■────■───────■──────┤ Ry(π/2) ├─┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├»
# «        ┌─┴─┐┌─┴─┐┌─┴─┐   ┌─┴─┐    ├─────────┴┐└─┬─┘└─┬─┘└─┬─┘└─┬─┘└─┬─┘└─┬─┘»
# «q132_3: ┤ X ├┤ X ├┤ X ├───┤ X ├────┤ Ry(-π/2) ├──■────■────■────■────■────■──»
# «        └───┘└───┘└───┘   └───┘    └──────────┘                              »
# «c132: 4/═════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «                               ┌───┐┌───┐┌───┐┌───┐┌───┐┌───┐┌───┐           »
# «q132_0: ───────────────────────┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├───────────»
# «        ┌─────────┐┌──────────┐└─┬─┘└─┬─┘└─┬─┘└─┬─┘└─┬─┘└─┬─┘└─┬─┘           »
# «q132_1: ┤ Rz(π/8) ├┤ Ry(-π/2) ├──■────■────■────■────■────■────■─────────────»
# «        └──┬───┬──┘├──────────┤┌───┐┌───┐┌───┐┌───┐┌───┐┌───┐┌───┐           »
# «q132_2: ───┤ X ├───┤ Ry(-π/4) ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├───────────»
# «           └─┬─┘   └──────────┘└─┬─┘└─┬─┘└─┬─┘└─┬─┘└─┬─┘└─┬─┘└─┬─┘┌─────────┐»
# «q132_3: ─────■───────────────────■────■────■────■────■────■────■──┤ Ry(π/2) ├»
# «                                                                  └─────────┘»
# «c132: 4/═════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «        ┌─┐
# «q132_0: ┤M├──────────────────
# «        └╥┘┌─┐
# «q132_1: ─╫─┤M├───────────────
# «         ║ └╥┘┌─┐
# «q132_2: ─╫──╫─┤M├────────────
# «         ║  ║ └╥┘┌───────┐┌─┐
# «q132_3: ─╫──╫──╫─┤ Rz(0) ├┤M├
# «         ║  ║  ║ └───────┘└╥┘
# «c132: 4/═╩══╩══╩═══════════╩═
# «         0  1  2           3

# %%
import qiskit.quantum_info as qi
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
import numpy as np

circ_new.remove_final_measurements()
wave_new = qi.Statevector.from_instruction(circ_new)

circs[0].remove_final_measurements()
wave = qi.Statevector.from_instruction(circs[0])

np.round(wave.data - wave_new.data,5)
# Out:
# array([0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j])

# %% [markdown]
# ### Hold Circuits

# %%
circ_new = create_hold_circ(0.111,circs[0])
circs_new = create_hold_circs(0.222,circs)

# %%
circs_new[4].draw()
# Out:
#         ┌───────┐┌──────────┐                                                 »
# q108_0: ┤ Rz(π) ├┤ Ry(-π/2) ├─────────────────────────────────────────────────»
#         ├───────┤├──────────┤                                                 »
# q108_1: ┤ Rz(0) ├┤ Ry(-π/2) ├─────────────────────────────────────────────────»
#         └─┬───┬─┘└┬───────┬─┘┌──────────┐     ┌───────────┐┌────────────┐     »
# q108_2: ──┤ X ├───┤ Rz(0) ├──┤ Ry(-π/2) ├──■──┤ Ry(0.222) ├┤ Ry(-0.222) ├──■──»
#           ├───┤   ├───────┤  └──────────┘┌─┴─┐└─┬───────┬─┘└────────────┘┌─┴─┐»
# q108_3: ──┤ X ├───┤ Rz(π) ├──────────────┤ X ├──┤ Ry(0) ├────────────────┤ X ├»
#           └───┘   └───────┘              └───┘  └───────┘                └───┘»
# c108: 4/══════════════════════════════════════════════════════════════════════»
#                                                                               »
# «                                                                              »
# «q108_0: ──────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q108_1: ──────────────────────────────────────────────────────────────────────»
# «        ┌───────────┐┌────────────┐┌─────────┐┌───┐  ┌───────┐                »
# «q108_2: ┤ Ry(0.222) ├┤ Ry(-0.222) ├┤ Ry(π/2) ├┤ X ├──┤ Ry(0) ├────────────────»
# «        └┬──────────┤└────────────┘└─────────┘└─┬─┘┌─┴───────┴─┐┌────────────┐»
# «q108_3: ─┤ Ry(-π/2) ├───────────────────────────■──┤ Ry(0.222) ├┤ Ry(-0.222) ├»
# «         └──────────┘                              └───────────┘└────────────┘»
# «c108: 4/══════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «                                                                            »
# «q108_0: ────────────────────────────────────────────────────────────────────»
# «                          ┌───────────┐ ┌────────────┐         ┌───────────┐»
# «q108_1: ───────────■──────┤ Ry(0.222) ├─┤ Ry(-0.222) ├────■────┤ Ry(0.222) ├»
# «        ┌───┐    ┌─┴─┐    └┬─────────┬┘ └────────────┘  ┌─┴─┐  └┬──────────┤»
# «q108_2: ┤ X ├────┤ X ├─────┤ Ry(π/2) ├──────────────────┤ X ├───┤ Ry(-π/2) ├»
# «        └─┬─┘┌───┴───┴───┐┌┴─────────┴─┐ ┌─────────┐  ┌─┴───┴─┐ └──────────┘»
# «q108_3: ──■──┤ Ry(0.222) ├┤ Ry(-0.222) ├─┤ Ry(π/2) ├──┤ Rz(0) ├─────────────»
# «             └───────────┘└────────────┘ └─────────┘  └───────┘             »
# «c108: 4/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «                                                                      »
# «q108_0: ──────────────────────────────────────────────────────────────»
# «        ┌────────────┐┌─────────┐┌───┐ ┌──────────┐              ┌───┐»
# «q108_1: ┤ Ry(-0.222) ├┤ Ry(π/2) ├┤ X ├─┤ Ry(-π/2) ├──────────────┤ X ├»
# «        └────────────┘└─────────┘└─┬─┘┌┴──────────┤┌────────────┐└─┬─┘»
# «q108_2: ───────────────────────────■──┤ Ry(0.222) ├┤ Ry(-0.222) ├──■──»
# «                                      └───────────┘└────────────┘     »
# «q108_3: ──────────────────────────────────────────────────────────────»
# «                                                                      »
# «c108: 4/══════════════════════════════════════════════════════════════»
# «                                                                      »
# «                     ┌───────────┐ ┌────────────┐         ┌───────────┐»
# «q108_0: ──────■──────┤ Ry(0.222) ├─┤ Ry(-0.222) ├────■────┤ Ry(0.222) ├»
# «            ┌─┴─┐    └┬─────────┬┘ └────────────┘  ┌─┴─┐  └┬──────────┤»
# «q108_1: ────┤ X ├─────┤ Ry(π/3) ├──────────────────┤ X ├───┤ Ry(-π/2) ├»
# «        ┌───┴───┴───┐┌┴─────────┴─┐ ┌─────────┐  ┌─┴───┴─┐ ├──────────┤»
# «q108_2: ┤ Ry(0.222) ├┤ Ry(-0.222) ├─┤ Ry(π/2) ├──┤ Rz(0) ├─┤ Ry(-π/2) ├»
# «        └───────────┘└────────────┘ └─────────┘  └───────┘ └──────────┘»
# «q108_3: ───────────────────────────────────────────────────────────────»
# «                                                                       »
# «c108: 4/═══════════════════════════════════════════════════════════════»
# «                                                                       »
# «        ┌────────────┐ ┌─────────┐     ┌───┐      ┌──────────┐              »
# «q108_0: ┤ Ry(-0.222) ├─┤ Ry(π/2) ├─────┤ X ├──────┤ Ry(-π/3) ├──────────────»
# «        └────────────┘ └─────────┘     └─┬─┘     ┌┴──────────┤┌────────────┐»
# «q108_1: ─────────────────────────────────■───────┤ Ry(0.222) ├┤ Ry(-0.222) ├»
# «                      ┌───────────┐┌────────────┐└───────────┘├───────────┬┘»
# «q108_2: ──────■───────┤ Ry(0.222) ├┤ Ry(-0.222) ├──────■──────┤ Ry(0.222) ├─»
# «            ┌─┴─┐     └┬─────────┬┘└────────────┘    ┌─┴─┐    └┬──────────┤ »
# «q108_3: ────┤ X ├──────┤ Ry(π/3) ├───────────────────┤ X ├─────┤ Ry(-π/2) ├─»
# «            └───┘      └─────────┘                   └───┘     └──────────┘ »
# «c108: 4/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «            ┌───┐      ┌──────────┐                                         »
# «q108_0: ────┤ X ├──────┤ Rz(-π/4) ├─────────────────────────────────────────»
# «            └─┬─┘     ┌┴──────────┤┌────────────┐ ┌─────────┐   ┌───────┐   »
# «q108_1: ──────■───────┤ Ry(0.222) ├┤ Ry(-0.222) ├─┤ Ry(π/2) ├───┤ Rz(0) ├───»
# «        ┌────────────┐└┬─────────┬┘└───┬───┬────┘ ├─────────┴┐  └───────┘   »
# «q108_2: ┤ Ry(-0.222) ├─┤ Ry(π/2) ├─────┤ X ├──────┤ Ry(-π/3) ├──────────────»
# «        └────────────┘ └─────────┘     └─┬─┘     ┌┴──────────┤┌────────────┐»
# «q108_3: ─────────────────────────────────■───────┤ Ry(0.222) ├┤ Ry(-0.222) ├»
# «                                                 └───────────┘└────────────┘»
# «c108: 4/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «                                                                       »
# «q108_0: ───────────────────────────────────────────────────────────────»
# «        ┌──────────┐              ┌───────────┐ ┌────────────┐         »
# «q108_1: ┤ Ry(-π/2) ├──────■───────┤ Ry(0.222) ├─┤ Ry(-0.222) ├────■────»
# «        └──┬───┬───┘    ┌─┴─┐    ┌┴───────────┴┐└────────────┘  ┌─┴─┐  »
# «q108_2: ───┤ X ├────────┤ X ├────┤ Ry(0.95532) ├────────────────┤ X ├──»
# «           └─┬─┘    ┌───┴───┴───┐└┬────────────┤ ┌─────────┐  ┌─┴───┴─┐»
# «q108_3: ─────■──────┤ Ry(0.222) ├─┤ Ry(-0.222) ├─┤ Ry(π/2) ├──┤ Rz(π) ├»
# «                    └───────────┘ └────────────┘ └─────────┘  └───────┘»
# «c108: 4/═══════════════════════════════════════════════════════════════»
# «                                                                       »
# «                                                                   »
# «q108_0: ───────────────────────────────────────────────────────────»
# «        ┌───────────┐┌────────────┐┌─────────┐┌───┐┌──────────────┐»
# «q108_1: ┤ Ry(0.222) ├┤ Ry(-0.222) ├┤ Ry(π/2) ├┤ X ├┤ Ry(-0.95532) ├»
# «        └┬──────────┤└────────────┘└─────────┘└─┬─┘└┬───────────┬─┘»
# «q108_2: ─┤ Ry(-π/2) ├───────────────────────────■───┤ Ry(0.222) ├──»
# «         └──────────┘                               └───────────┘  »
# «q108_3: ───────────────────────────────────────────────────────────»
# «                                                                   »
# «c108: 4/═══════════════════════════════════════════════════════════»
# «                                                                   »
# «                                            ┌───┐                  »
# «q108_0: ────────────────────────────────────┤ X ├──────────────────»
# «                      ┌───┐ ┌─────────┐     └─┬─┘     ┌───────────┐»
# «q108_1: ──────────────┤ X ├─┤ Rz(π/4) ├───────■───────┤ Ry(0.222) ├»
# «        ┌────────────┐└─┬─┘┌┴─────────┴┐┌────────────┐└┬─────────┬┘»
# «q108_2: ┤ Ry(-0.222) ├──■──┤ Ry(0.222) ├┤ Ry(-0.222) ├─┤ Ry(π/2) ├─»
# «        └────────────┘     └───────────┘└────────────┘ └─────────┘ »
# «q108_3: ───────────────────────────────────────────────────────────»
# «                                                                   »
# «c108: 4/═══════════════════════════════════════════════════════════»
# «                                                                   »
# «                                                          ┌───────────┐ »
# «q108_0: ───────────────────────────────────────────■──────┤ Ry(0.222) ├─»
# «        ┌────────────┐┌─────────┐ ┌─────────┐    ┌─┴─┐    └┬──────────┤ »
# «q108_1: ┤ Ry(-0.222) ├┤ Ry(π/2) ├─┤ Rz(π/8) ├────┤ X ├─────┤ Rz(-π/4) ├─»
# «        └─┬───────┬──┘├─────────┴┐└─────────┘┌───┴───┴───┐┌┴──────────┴┐»
# «q108_2: ──┤ Rz(0) ├───┤ Ry(-π/2) ├─────■─────┤ Ry(0.222) ├┤ Ry(-0.222) ├»
# «          └───────┘   └──────────┘   ┌─┴─┐   └┬─────────┬┘└────────────┘»
# «q108_3: ─────────────────────────────┤ X ├────┤ Ry(π/4) ├───────────────»
# «                                     └───┘    └─────────┘               »
# «c108: 4/════════════════════════════════════════════════════════════════»
# «                                                                        »
# «        ┌────────────┐             ┌───────────┐ ┌────────────┐┌───┐»
# «q108_0: ┤ Ry(-0.222) ├──────■──────┤ Ry(0.222) ├─┤ Ry(-0.222) ├┤ X ├»
# «        └────────────┘    ┌─┴─┐    └┬─────────┬┘ └┬──────────┬┘└─┬─┘»
# «q108_1: ──────────────────┤ X ├─────┤ Rz(π/8) ├───┤ Ry(-π/2) ├───■──»
# «                      ┌───┴───┴───┐┌┴─────────┴─┐ ├─────────┬┘ ┌───┐»
# «q108_2: ──────■───────┤ Ry(0.222) ├┤ Ry(-0.222) ├─┤ Ry(π/2) ├──┤ X ├»
# «            ┌─┴─┐     └┬──────────┤└────────────┘ └─────────┘  └─┬─┘»
# «q108_3: ────┤ X ├──────┤ Ry(-π/2) ├──────────────────────────────■──»
# «            └───┘      └──────────┘                                 »
# «c108: 4/════════════════════════════════════════════════════════════»
# «                                                                    »
# «                     ┌─┐                                                    »
# «q108_0: ─────────────┤M├────────────────────────────────────────────────────»
# «        ┌───────────┐└╥┘┌────────────┐     ┌─┐                              »
# «q108_1: ┤ Ry(0.222) ├─╫─┤ Ry(-0.222) ├─────┤M├──────────────────────────────»
# «        └┬──────────┤ ║ └────────────┘┌───┐└╥┘             ┌─┐              »
# «q108_2: ─┤ Ry(-π/4) ├─╫───────────────┤ X ├─╫──────────────┤M├──────────────»
# «        ┌┴──────────┤ ║ ┌────────────┐└─┬─┘ ║ ┌───────────┐└╥┘┌────────────┐»
# «q108_3: ┤ Ry(0.222) ├─╫─┤ Ry(-0.222) ├──■───╫─┤ Ry(0.222) ├─╫─┤ Ry(-0.222) ├»
# «        └───────────┘ ║ └────────────┘      ║ └───────────┘ ║ └────────────┘»
# «c108: 4/══════════════╩═════════════════════╩═══════════════╩═══════════════»
# «                      0                     1               2               »
# «
# «q108_0: ───────────────────────
# «
# «q108_1: ───────────────────────
# «
# «q108_2: ───────────────────────
# «        ┌─────────┐┌───────┐┌─┐
# «q108_3: ┤ Ry(π/2) ├┤ Rz(0) ├┤M├
# «        └─────────┘└───────┘└╥┘
# «c108: 4/═════════════════════╩═
# «                             3

# %%
circ_new.draw()
# Out:
#         ┌───────┐┌──────────┐                                                 »
# q169_0: ┤ Rz(π) ├┤ Ry(-π/2) ├─────────────────────────────────────────────────»
#         ├───────┤├──────────┤                                                 »
# q169_1: ┤ Rz(0) ├┤ Ry(-π/2) ├─────────────────────────────────────────────────»
#         └─┬───┬─┘└┬───────┬─┘┌──────────┐     ┌───────────┐┌────────────┐     »
# q169_2: ──┤ X ├───┤ Rz(0) ├──┤ Ry(-π/2) ├──■──┤ ry(0.111) ├┤ ry(-0.111) ├──■──»
#           ├───┤   ├───────┴┐ └──────────┘┌─┴─┐└─┬───────┬─┘└────────────┘┌─┴─┐»
# q169_3: ──┤ X ├───┤ Rz(-π) ├─────────────┤ X ├──┤ Ry(0) ├────────────────┤ X ├»
#           └───┘   └────────┘             └───┘  └───────┘                └───┘»
# c169: 4/══════════════════════════════════════════════════════════════════════»
#                                                                               »
# «                                                                              »
# «q169_0: ──────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q169_1: ──────────────────────────────────────────────────────────────────────»
# «        ┌───────────┐┌────────────┐┌─────────┐┌───┐  ┌───────┐                »
# «q169_2: ┤ ry(0.111) ├┤ ry(-0.111) ├┤ Ry(π/2) ├┤ X ├──┤ Ry(0) ├────────────────»
# «        └┬──────────┤└────────────┘└─────────┘└─┬─┘┌─┴───────┴─┐┌────────────┐»
# «q169_3: ─┤ Ry(-π/2) ├───────────────────────────■──┤ ry(0.111) ├┤ ry(-0.111) ├»
# «         └──────────┘                              └───────────┘└────────────┘»
# «c169: 4/══════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «                                                                            »
# «q169_0: ────────────────────────────────────────────────────────────────────»
# «                          ┌───────────┐ ┌────────────┐         ┌───────────┐»
# «q169_1: ───────────■──────┤ ry(0.111) ├─┤ ry(-0.111) ├────■────┤ ry(0.111) ├»
# «        ┌───┐    ┌─┴─┐    └┬─────────┬┘ └────────────┘  ┌─┴─┐  └┬──────────┤»
# «q169_2: ┤ X ├────┤ X ├─────┤ Ry(π/2) ├──────────────────┤ X ├───┤ Ry(-π/2) ├»
# «        └─┬─┘┌───┴───┴───┐┌┴─────────┴─┐ ┌─────────┐  ┌─┴───┴─┐ └──────────┘»
# «q169_3: ──■──┤ ry(0.111) ├┤ ry(-0.111) ├─┤ Ry(π/2) ├──┤ Rz(π) ├─────────────»
# «             └───────────┘└────────────┘ └─────────┘  └───────┘             »
# «c169: 4/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «                                                                      »
# «q169_0: ──────────────────────────────────────────────────────────────»
# «        ┌────────────┐┌─────────┐┌───┐ ┌──────────┐              ┌───┐»
# «q169_1: ┤ ry(-0.111) ├┤ Ry(π/2) ├┤ X ├─┤ Ry(-π/2) ├──────────────┤ X ├»
# «        └────────────┘└─────────┘└─┬─┘┌┴──────────┤┌────────────┐└─┬─┘»
# «q169_2: ───────────────────────────■──┤ ry(0.111) ├┤ ry(-0.111) ├──■──»
# «                                      └───────────┘└────────────┘     »
# «q169_3: ──────────────────────────────────────────────────────────────»
# «                                                                      »
# «c169: 4/══════════════════════════════════════════════════════════════»
# «                                                                      »
# «                     ┌───────────┐ ┌────────────┐         ┌───────────┐»
# «q169_0: ──────■──────┤ ry(0.111) ├─┤ ry(-0.111) ├────■────┤ ry(0.111) ├»
# «            ┌─┴─┐    └┬─────────┬┘ └────────────┘  ┌─┴─┐  └┬──────────┤»
# «q169_1: ────┤ X ├─────┤ Ry(π/3) ├──────────────────┤ X ├───┤ Ry(-π/2) ├»
# «        ┌───┴───┴───┐┌┴─────────┴─┐ ┌─────────┐  ┌─┴───┴─┐ ├──────────┤»
# «q169_2: ┤ ry(0.111) ├┤ ry(-0.111) ├─┤ Ry(π/2) ├──┤ Rz(π) ├─┤ Ry(-π/2) ├»
# «        └───────────┘└────────────┘ └─────────┘  └───────┘ └──────────┘»
# «q169_3: ───────────────────────────────────────────────────────────────»
# «                                                                       »
# «c169: 4/═══════════════════════════════════════════════════════════════»
# «                                                                       »
# «        ┌────────────┐ ┌─────────┐     ┌───┐      ┌──────────┐              »
# «q169_0: ┤ ry(-0.111) ├─┤ Ry(π/2) ├─────┤ X ├──────┤ Ry(-π/3) ├──────────────»
# «        └────────────┘ └─────────┘     └─┬─┘     ┌┴──────────┤┌────────────┐»
# «q169_1: ─────────────────────────────────■───────┤ ry(0.111) ├┤ ry(-0.111) ├»
# «                      ┌───────────┐┌────────────┐└───────────┘├───────────┬┘»
# «q169_2: ──────■───────┤ ry(0.111) ├┤ ry(-0.111) ├──────■──────┤ ry(0.111) ├─»
# «            ┌─┴─┐     └─┬───────┬─┘└────────────┘    ┌─┴─┐    └┬──────────┤ »
# «q169_3: ────┤ X ├───────┤ Ry(0) ├────────────────────┤ X ├─────┤ Ry(-π/2) ├─»
# «            └───┘       └───────┘                    └───┘     └──────────┘ »
# «c169: 4/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «            ┌───┐                  ┌─┐                           »
# «q169_0: ────┤ X ├──────────────────┤M├───────────────────────────»
# «            └─┬─┘     ┌───────────┐└╥┘┌────────────┐ ┌─────────┐ »
# «q169_1: ──────■───────┤ ry(0.111) ├─╫─┤ ry(-0.111) ├─┤ Ry(π/2) ├─»
# «        ┌────────────┐└┬─────────┬┘ ║ └───┬───┬────┘ └┬───────┬┘ »
# «q169_2: ┤ ry(-0.111) ├─┤ Ry(π/2) ├──╫─────┤ X ├───────┤ Ry(0) ├──»
# «        └────────────┘ └─────────┘  ║     └─┬─┘     ┌─┴───────┴─┐»
# «q169_3: ────────────────────────────╫───────■───────┤ ry(0.111) ├»
# «                                    ║               └───────────┘»
# «c169: 4/════════════════════════════╩════════════════════════════»
# «                                    0                            »
# «                                                                            »
# «q169_0: ────────────────────────────────────────────────────────────────────»
# «          ┌───────┐   ┌──────────┐              ┌───────────┐ ┌────────────┐»
# «q169_1: ──┤ Rz(0) ├───┤ Ry(-π/2) ├──────■───────┤ ry(0.111) ├─┤ ry(-0.111) ├»
# «          └───────┘   └──┬───┬───┘    ┌─┴─┐    ┌┴───────────┴┐└────────────┘»
# «q169_2: ─────────────────┤ X ├────────┤ X ├────┤ Ry(0.95532) ├──────────────»
# «        ┌────────────┐   └─┬─┘    ┌───┴───┴───┐└┬────────────┤ ┌─────────┐  »
# «q169_3: ┤ ry(-0.111) ├─────■──────┤ ry(0.111) ├─┤ ry(-0.111) ├─┤ Ry(π/2) ├──»
# «        └────────────┘            └───────────┘ └────────────┘ └─────────┘  »
# «c169: 4/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «                                                                            »
# «q169_0: ────────────────────────────────────────────────────────────────────»
# «                 ┌───────────┐┌────────────┐┌─────────┐┌───┐┌──────────────┐»
# «q169_1: ────■────┤ ry(0.111) ├┤ ry(-0.111) ├┤ Ry(π/2) ├┤ X ├┤ Ry(-0.95532) ├»
# «          ┌─┴─┐  └┬──────────┤└────────────┘└─────────┘└─┬─┘└┬───────────┬─┘»
# «q169_2: ──┤ X ├───┤ Ry(-π/2) ├───────────────────────────■───┤ ry(0.111) ├──»
# «        ┌─┴───┴─┐ └──────────┘                               └───────────┘  »
# «q169_3: ┤ Rz(0) ├───────────────────────────────────────────────────────────»
# «        └───────┘                                                           »
# «c169: 4/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «                                                                             »
# «q169_0: ─────────────────────────────────────────────────────────────────────»
# «                      ┌───┐             ┌─┐                                  »
# «q169_1: ──────────────┤ X ├─────────────┤M├──────────────────────────────────»
# «        ┌────────────┐└─┬─┘┌───────────┐└╥┘┌────────────┐┌─────────┐┌───────┐»
# «q169_2: ┤ ry(-0.111) ├──■──┤ ry(0.111) ├─╫─┤ ry(-0.111) ├┤ Ry(π/2) ├┤ Rz(0) ├»
# «        └────────────┘     └───────────┘ ║ └────────────┘└─────────┘└───────┘»
# «q169_3: ─────────────────────────────────╫───────────────────────────────────»
# «                                         ║                                   »
# «c169: 4/═════════════════════════════════╩═══════════════════════════════════»
# «                                         1                                   »
# «                                                                      »
# «q169_0: ──────────────────────────────────────────────────────────────»
# «                                                                      »
# «q169_1: ──────────────────────────────────────────────────────────────»
# «        ┌──────────┐     ┌───────────┐┌────────────┐     ┌───────────┐»
# «q169_2: ┤ Ry(-π/2) ├──■──┤ ry(0.111) ├┤ ry(-0.111) ├──■──┤ ry(0.111) ├»
# «        └──────────┘┌─┴─┐└┬─────────┬┘└────────────┘┌─┴─┐└┬──────────┤»
# «q169_3: ────────────┤ X ├─┤ Ry(π/4) ├───────────────┤ X ├─┤ Ry(-π/2) ├»
# «                    └───┘ └─────────┘               └───┘ └──────────┘»
# «c169: 4/══════════════════════════════════════════════════════════════»
# «                                                                      »
# «                                                                      »
# «q169_0: ──────────────────────────────────────────────────────────────»
# «                                                                      »
# «q169_1: ──────────────────────────────────────────────────────────────»
# «        ┌────────────┐┌─────────┐┌───┐ ┌──────────┐              ┌───┐»
# «q169_2: ┤ ry(-0.111) ├┤ Ry(π/2) ├┤ X ├─┤ Ry(-π/4) ├──────────────┤ X ├»
# «        └────────────┘└─────────┘└─┬─┘┌┴──────────┤┌────────────┐└─┬─┘»
# «q169_3: ───────────────────────────■──┤ ry(0.111) ├┤ ry(-0.111) ├──■──»
# «                                      └───────────┘└────────────┘     »
# «c169: 4/══════════════════════════════════════════════════════════════»
# «                                                                      »
# «
# «q169_0: ─────────────────────────────────────────────────────
# «
# «q169_1: ─────────────────────────────────────────────────────
# «                     ┌─┐
# «q169_2: ─────────────┤M├─────────────────────────────────────
# «        ┌───────────┐└╥┘┌────────────┐┌─────────┐┌───────┐┌─┐
# «q169_3: ┤ ry(0.111) ├─╫─┤ ry(-0.111) ├┤ Ry(π/2) ├┤ Rz(0) ├┤M├
# «        └───────────┘ ║ └────────────┘└─────────┘└───────┘└╥┘
# «c169: 4/══════════════╩════════════════════════════════════╩═
# «                      2                                    3

# %%
print_circ(circ_new)
# Out:
# [[0, 'x', 2, array([], dtype=float64)],
#  [1, 'x', 3, array([], dtype=float64)],
#  [2, 'rz', 0, array([3.142])],
#  [3, 'rz', 1, array([0.])],
#  [4, 'rz', 2, array([0.])],
#  [5, 'rz', 3, array([-3.142])],
#  [6, 'ry', 2, array([-1.571])],
#  [7, 'cx', 2, array([], dtype=float64)],
#  [8, 'ry', 2, array([0.111])],
#  [9, 'ry', 2, array([-0.111])],
#  [10, 'ry', 3, array([0.])],
#  [11, 'cx', 2, array([], dtype=float64)],
#  [12, 'ry', 2, array([0.111])],
#  [13, 'ry', 2, array([-0.111])],
#  [14, 'ry', 2, array([1.571])],
#  [15, 'ry', 3, array([-1.571])],
#  [16, 'cx', 3, array([], dtype=float64)],
#  [17, 'ry', 3, array([0.111])],
#  [18, 'ry', 3, array([-0.111])],
#  [19, 'ry', 2, array([-0.])],
#  [20, 'cx', 3, array([], dtype=float64)],
#  [21, 'ry', 3, array([0.111])],
#  [22, 'ry', 3, array([-0.111])],
#  [23, 'ry', 3, array([1.571])],
#  [24, 'rz', 3, array([3.142])],
#  [25, 'ry', 1, array([-1.571])],
#  [26, 'cx', 1, array([], dtype=float64)],
#  [27, 'ry', 1, array([0.111])],
#  [28, 'ry', 1, array([-0.111])],
#  [29, 'ry', 2, array([1.571])],
#  [30, 'cx', 1, array([], dtype=float64)],
#  [31, 'ry', 1, array([0.111])],
#  [32, 'ry', 1, array([-0.111])],
#  [33, 'ry', 1, array([1.571])],
#  [34, 'ry', 2, array([-1.571])],
#  [35, 'cx', 2, array([], dtype=float64)],
#  [36, 'ry', 2, array([0.111])],
#  [37, 'ry', 2, array([-0.111])],
#  [38, 'ry', 1, array([-1.571])],
#  [39, 'cx', 2, array([], dtype=float64)],
#  [40, 'ry', 2, array([0.111])],
#  [41, 'ry', 2, array([-0.111])],
#  [42, 'ry', 2, array([1.571])],
#  [43, 'rz', 2, array([3.142])],
#  [44, 'ry', 2, array([-1.571])],
#  [45, 'cx', 2, array([], dtype=float64)],
#  [46, 'ry', 2, array([0.111])],
#  [47, 'ry', 2, array([-0.111])],
#  [48, 'ry', 3, array([0.])],
#  [49, 'cx', 2, array([], dtype=float64)],
#  [50, 'ry', 2, array([0.111])],
#  [51, 'ry', 2, array([-0.111])],
#  [52, 'ry', 2, array([1.571])],
#  [53, 'ry', 3, array([-1.571])],
#  [54, 'cx', 3, array([], dtype=float64)],
#  [55, 'ry', 3, array([0.111])],
#  [56, 'ry', 3, array([-0.111])],
#  [57, 'ry', 2, array([-0.])],
#  [58, 'cx', 3, array([], dtype=float64)],
#  [59, 'ry', 3, array([0.111])],
#  [60, 'ry', 3, array([-0.111])],
#  [61, 'ry', 3, array([1.571])],
#  [62, 'rz', 3, array([-0.])],
#  [63, 'ry', 0, array([-1.571])],
#  [64, 'cx', 0, array([], dtype=float64)],
#  [65, 'ry', 0, array([0.111])],
#  [66, 'ry', 0, array([-0.111])],
#  [67, 'ry', 1, array([1.047])],
#  [68, 'cx', 0, array([], dtype=float64)],
#  [69, 'ry', 0, array([0.111])],
#  [70, 'ry', 0, array([-0.111])],
#  [71, 'ry', 0, array([1.571])],
#  [72, 'ry', 1, array([-1.571])],
#  [73, 'cx', 1, array([], dtype=float64)],
#  [74, 'ry', 1, array([0.111])],
#  [75, 'ry', 1, array([-0.111])],
#  [76, 'ry', 0, array([-1.047])],
#  [77, 'cx', 1, array([], dtype=float64)],
#  [78, 'ry', 1, array([0.111])],
#  [79, 'ry', 1, array([-0.111])],
#  [80, 'ry', 1, array([1.571])],
#  [81, 'rz', 1, array([-0.])],
#  [82, 'ry', 1, array([-1.571])],
#  [83, 'cx', 1, array([], dtype=float64)],
#  [84, 'ry', 1, array([0.111])],
#  [85, 'ry', 1, array([-0.111])],
#  [86, 'ry', 2, array([0.955])],
#  [87, 'cx', 1, array([], dtype=float64)],
#  [88, 'ry', 1, array([0.111])],
#  [89, 'ry', 1, array([-0.111])],
#  [90, 'ry', 1, array([1.571])],
#  [91, 'ry', 2, array([-1.571])],
#  [92, 'cx', 2, array([], dtype=float64)],
#  [93, 'ry', 2, array([0.111])],
#  [94, 'ry', 2, array([-0.111])],
#  [95, 'ry', 1, array([-0.955])],
#  [96, 'cx', 2, array([], dtype=float64)],
#  [97, 'ry', 2, array([0.111])],
#  [98, 'ry', 2, array([-0.111])],
#  [99, 'ry', 2, array([1.571])],
#  [100, 'rz', 2, array([-0.])],
#  [101, 'ry', 2, array([-1.571])],
#  [102, 'cx', 2, array([], dtype=float64)],
#  [103, 'ry', 2, array([0.111])],
#  [104, 'ry', 2, array([-0.111])],
#  [105, 'ry', 3, array([0.785])],
#  [106, 'cx', 2, array([], dtype=float64)],
#  [107, 'ry', 2, array([0.111])],
#  [108, 'ry', 2, array([-0.111])],
#  [109, 'ry', 2, array([1.571])],
#  [110, 'ry', 3, array([-1.571])],
#  [111, 'cx', 3, array([], dtype=float64)],
#  [112, 'ry', 3, array([0.111])],
#  [113, 'ry', 3, array([-0.111])],
#  [114, 'ry', 2, array([-0.785])],
#  [115, 'cx', 3, array([], dtype=float64)],
#  [116, 'ry', 3, array([0.111])],
#  [117, 'ry', 3, array([-0.111])],
#  [118, 'ry', 3, array([1.571])],
#  [119, 'rz', 3, array([-0.])],
#  [120, 'measure', 0, array([], dtype=float64)],
#  [121, 'measure', 1, array([], dtype=float64)],
#  [122, 'measure', 2, array([], dtype=float64)],
#  [123, 'measure', 3, array([], dtype=float64)]]

# %%
import qiskit.quantum_info as qi
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit

circ_new.remove_final_measurements()
wave_new = qi.Statevector.from_instruction(circ_new)

circs[0].remove_final_measurements()
wave = qi.Statevector.from_instruction(circs[0])

np.round(wave.data - wave_new.data,5)
# Out:
# array([-0.+0.j, -0.+0.j, -0.-0.j,  0.-0.j,  0.-0.j,  0.+0.j, -0.-0.j,
#        -0.+0.j, -0.-0.j, -0.-0.j,  0.+0.j,  0.-0.j,  0.+0.j, -0.+0.j,
#        -0.-0.j,  0.-0.j])
