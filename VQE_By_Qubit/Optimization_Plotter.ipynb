# %%
T = 2
A = 10
a = 0.05
c = 0.4
beta = 0.201
gamma = 0.101
x = 1
y = 2
z = 3

# %%
import pickle

c=2.0
file_to_read = open("VQE_ByQubit"+str(T)+"_A_"+str(A)+"_a_"+str(a)+"_c_"+str(c)+"_beta_"+str(beta)+"_gamma_"+str(gamma)+"_x_"+str(x)+"_y_"+str(y)+"_z_"+str(z)+".pickle", "rb")
loaded_object_c2 = pickle.load(file_to_read)

c=1.0
file_to_read = open("VQE_ByQubit"+str(T)+"_A_"+str(A)+"_a_"+str(a)+"_c_"+str(c)+"_beta_"+str(beta)+"_gamma_"+str(gamma)+"_x_"+str(x)+"_y_"+str(y)+"_z_"+str(z)+".pickle", "rb")
loaded_object_c1 = pickle.load(file_to_read)

c=0.4
file_to_read = open("VQE_ByQubit"+str(T)+"_A_"+str(A)+"_a_"+str(a)+"_c_"+str(c)+"_beta_"+str(beta)+"_gamma_"+str(gamma)+"_x_"+str(x)+"_y_"+str(y)+"_z_"+str(z)+".pickle", "rb")
loaded_object_c04 = pickle.load(file_to_read)


c = 0.2
file_to_read = open("VQE_ByQubit"+str(T)+"_A_"+str(A)+"_a_"+str(a)+"_c_"+str(c)+"_beta_"+str(beta)+"_gamma_"+str(gamma)+"_x_"+str(x)+"_y_"+str(y)+"_z_"+str(z)+".pickle", "rb")
loaded_object_c02 = pickle.load(file_to_read)

c = 0.05
file_to_read = open("VQE_ByQubit"+str(T)+"_A_"+str(A)+"_a_"+str(a)+"_c_"+str(c)+"_beta_"+str(beta)+"_gamma_"+str(gamma)+"_x_"+str(x)+"_y_"+str(y)+"_z_"+str(z)+".pickle", "rb")
loaded_object_c005 = pickle.load(file_to_read)

c = 0.01
file_to_read = open("VQE_ByQubit"+str(T)+"_A_"+str(A)+"_a_"+str(a)+"_c_"+str(c)+"_beta_"+str(beta)+"_gamma_"+str(gamma)+"_x_"+str(x)+"_y_"+str(y)+"_z_"+str(z)+".pickle", "rb")
loaded_object_c001 = pickle.load(file_to_read)

c = 0.001
file_to_read = open("VQE_ByQubit"+str(T)+"_A_"+str(A)+"_a_"+str(a)+"_c_"+str(c)+"_beta_"+str(beta)+"_gamma_"+str(gamma)+"_x_"+str(x)+"_y_"+str(y)+"_z_"+str(z)+".pickle", "rb")
loaded_object_c0001 = pickle.load(file_to_read)

c = 1e-10
file_to_read = open("VQE_ByQubit"+str(T)+"_A_"+str(A)+"_a_"+str(a)+"_c_"+str(c)+"_beta_"+str(beta)+"_gamma_"+str(gamma)+"_x_"+str(x)+"_y_"+str(y)+"_z_"+str(z)+".pickle", "rb")
loaded_object_c0 = pickle.load(file_to_read)

# %%
import matplotlib.pyplot as plt

El_c1 = [loaded_object_c1[i]['E'] for i in range(len(loaded_object_c04))]
El_c2 = [loaded_object_c2[i]['E'] for i in range(len(loaded_object_c04))]
El_c04 = [loaded_object_c04[i]['E'] for i in range(len(loaded_object_c04))]
El_c02 = [loaded_object_c02[i]['E'] for i in range(len(loaded_object_c02))]
El_c005 = [loaded_object_c005[i]['E'] for i in range(len(loaded_object_c02))]
El_c001 = [loaded_object_c001[i]['E'] for i in range(len(loaded_object_c02))]
El_c0001 = [loaded_object_c0001[i]['E'] for i in range(len(loaded_object_c02))]
El_c0 = [loaded_object_c0[i]['E'] for i in range(len(loaded_object_c02))]
tl = [i for i in range(len(El_c1))]

plt.plot(tl,El_c2,label = "c = 2.0")
plt.plot(tl,El_c1,label = "c = 1.0")
plt.plot(tl,El_c04,label = "c = 0.4")
plt.plot(tl,El_c02,label = "c = 0.2")
plt.plot(tl,El_c005,label = "c = 0.05")
plt.plot(tl,El_c001,label = "c = 0.01")
plt.plot(tl,El_c0001,label = "c = 0.001")
plt.plot(tl,El_c0,label = "c = $10^{-10}$")
plt.legend()

# %% [markdown]
# The smaller c is, the more accurate is the derivative.

# %%
T = 2
A = 10
a = 0.05
c = 0.2
beta = 0.201
gamma = 0.101
x = 1
y = 2
z = 3

# %%
A = 10
file_to_read = open("VQE_ByQubit"+str(T)+"_A_"+str(A)+"_a_"+str(a)+"_c_"+str(c)+"_beta_"+str(beta)+"_gamma_"+str(gamma)+"_x_"+str(x)+"_y_"+str(y)+"_z_"+str(z)+".pickle", "rb")
loaded_object_A10 = pickle.load(file_to_read)

A = 5
file_to_read = open("VQE_ByQubit"+str(T)+"_A_"+str(A)+"_a_"+str(a)+"_c_"+str(c)+"_beta_"+str(beta)+"_gamma_"+str(gamma)+"_x_"+str(x)+"_y_"+str(y)+"_z_"+str(z)+".pickle", "rb")
loaded_object_A5 = pickle.load(file_to_read)

A = 0
file_to_read = open("VQE_ByQubit"+str(T)+"_A_"+str(A)+"_a_"+str(a)+"_c_"+str(c)+"_beta_"+str(beta)+"_gamma_"+str(gamma)+"_x_"+str(x)+"_y_"+str(y)+"_z_"+str(z)+".pickle", "rb")
loaded_object_A0 = pickle.load(file_to_read)

# %%
El_A0 = [loaded_object_A0[i]['E'] for i in range(len(loaded_object_A5))]
El_A5 = [loaded_object_A5[i]['E'] for i in range(len(loaded_object_A5))]
El_A10 = [loaded_object_A10[i]['E'] for i in range(len(loaded_object_A10))]


plt.plot(tl,El_A0,label = "A = 0")
plt.plot(tl,El_A5,label = "A = 5")
plt.plot(tl,El_A10,label = "A = 10")
plt.legend()

# %%
T = 2
A = 0
a = 0.05
c = 0.2
beta = 0.201
gamma = 0.101
x = 1
y = 2
z = 3

# %%
a = 0.01
file_to_read = open("VQE_ByQubit"+str(T)+"_A_"+str(A)+"_a_"+str(a)+"_c_"+str(c)+"_beta_"+str(beta)+"_gamma_"+str(gamma)+"_x_"+str(x)+"_y_"+str(y)+"_z_"+str(z)+".pickle", "rb")
loaded_object_a001 = pickle.load(file_to_read)

a = 0.03
file_to_read = open("VQE_ByQubit"+str(T)+"_A_"+str(A)+"_a_"+str(a)+"_c_"+str(c)+"_beta_"+str(beta)+"_gamma_"+str(gamma)+"_x_"+str(x)+"_y_"+str(y)+"_z_"+str(z)+".pickle", "rb")
loaded_object_a003 = pickle.load(file_to_read)

a = 0.04
file_to_read = open("VQE_ByQubit"+str(T)+"_A_"+str(A)+"_a_"+str(a)+"_c_"+str(c)+"_beta_"+str(beta)+"_gamma_"+str(gamma)+"_x_"+str(x)+"_y_"+str(y)+"_z_"+str(z)+".pickle", "rb")
loaded_object_a004 = pickle.load(file_to_read)

a = 0.05
file_to_read = open("VQE_ByQubit"+str(T)+"_A_"+str(A)+"_a_"+str(a)+"_c_"+str(c)+"_beta_"+str(beta)+"_gamma_"+str(gamma)+"_x_"+str(x)+"_y_"+str(y)+"_z_"+str(z)+".pickle", "rb")
loaded_object_a005 = pickle.load(file_to_read)

a = 0.08
file_to_read = open("VQE_ByQubit"+str(T)+"_A_"+str(A)+"_a_"+str(a)+"_c_"+str(c)+"_beta_"+str(beta)+"_gamma_"+str(gamma)+"_x_"+str(x)+"_y_"+str(y)+"_z_"+str(z)+".pickle", "rb")
loaded_object_a008 = pickle.load(file_to_read)

a = 0.1
file_to_read = open("VQE_ByQubit"+str(T)+"_A_"+str(A)+"_a_"+str(a)+"_c_"+str(c)+"_beta_"+str(beta)+"_gamma_"+str(gamma)+"_x_"+str(x)+"_y_"+str(y)+"_z_"+str(z)+".pickle", "rb")
loaded_object_a01 = pickle.load(file_to_read)

# %%
El_a001 = [loaded_object_a001[i]['E'] for i in range(len(loaded_object_A5))]
El_a003 = [loaded_object_a003[i]['E'] for i in range(len(loaded_object_A5))]
El_a004 = [loaded_object_a004[i]['E'] for i in range(len(loaded_object_A5))]
El_a005 = [loaded_object_a005[i]['E'] for i in range(len(loaded_object_A5))]
El_a008 = [loaded_object_a008[i]['E'] for i in range(len(loaded_object_A5))]
El_a01 = [loaded_object_a01[i]['E'] for i in range(len(loaded_object_A10))]


plt.plot(tl,El_a001,label = "a = 0.01")
plt.plot(tl,El_a003,label = "a = 0.03")
plt.plot(tl,El_a004,label = "a = 0.04")
plt.plot(tl,El_a005,label = "a = 0.05")
plt.plot(tl,El_a008,label = "a = 0.08")
plt.plot(tl,El_a01,label = "A = 0.1")
plt.legend()
