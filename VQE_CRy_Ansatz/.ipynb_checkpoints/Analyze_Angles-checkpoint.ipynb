# %%
import pickle
T=1
beta = 0.201 #0.05 #0.201
A = 10 #10
a = 0.05  #0.05
gamma = 0.101
c = 0.4
beta_a = beta
A_a = A
a_a = a
gamma_a = gamma
c_a = c
u=4.0
t=-1
tt = t



fpath = '/Users/stenger/Documents/Research/Hubbard_symmetries/VQE_CRY_Ansatz/Data/'

file_to_read = open(fpath + "VQE_matrix_new_T_"+str(T)+"_A_"+str(A)+"_a_"+str(a)+"_c_"+str(c)+"_beta_"+str(beta)+"_gamma_"+str(gamma)+"_t_"+str(t)+"_u_"+str(u)+".pickle", "rb")

loaded_object = pickle.load(file_to_read)

# %%
kl = [k for k in range(len(loaded_object))]
E = [loaded_object[k]['E'] for k in range(len(loaded_object))]

print(E[1999])
plt.plot(kl,E)
# Out:
# -1.4719280421768721

# %%
b=1
kl = [k for k in range(len(loaded_object))]
phi10 = [loaded_object[k]['phi'][b][0] for k in range(len(loaded_object))]
phi11 = [loaded_object[k]['phi'][b][1] for k in range(len(loaded_object))]
phi12 = [loaded_object[k]['phi'][b][2] for k in range(len(loaded_object))]
phi13 = [loaded_object[k]['phi'][b][3] for k in range(len(loaded_object))]
phi14 = [loaded_object[k]['phi'][b][4] for k in range(len(loaded_object))]
b=2
phi20 = [loaded_object[k]['phi'][b][0] for k in range(len(loaded_object))]
phi21 = [loaded_object[k]['phi'][b][1] for k in range(len(loaded_object))]
phi22 = [loaded_object[k]['phi'][b][2] for k in range(len(loaded_object))]
phi23 = [loaded_object[k]['phi'][b][3] for k in range(len(loaded_object))]
phi24 = [loaded_object[k]['phi'][b][4] for k in range(len(loaded_object))]

# %%
import matplotlib.pyplot as plt

plt.plot(kl,phi10)
plt.plot(kl,phi11)
plt.plot(kl,phi12)
plt.plot(kl,phi13)
plt.plot(kl,phi14)

# %%
plt.plot(kl,phi20)
plt.plot(kl,phi21)
plt.plot(kl,phi22)
plt.plot(kl,phi23)
plt.plot(kl,phi24)

# %%
b=4
kl = [k for k in range(len(loaded_object))]
phib0 = [loaded_object[k]['phi'][b][0] for k in range(len(loaded_object))]
phib1 = [loaded_object[k]['phi'][b][1] for k in range(len(loaded_object))]
phib2 = [loaded_object[k]['phi'][b][2] for k in range(len(loaded_object))]
phib3 = [loaded_object[k]['phi'][b][3] for k in range(len(loaded_object))]
phib4 = [loaded_object[k]['phi'][b][4] for k in range(len(loaded_object))]

plt.plot(kl,phib0)
plt.plot(kl,phib1)
plt.plot(kl,phib2)
plt.plot(kl,phib3)
plt.plot(kl,phib4)

# %%
alpha0 = [loaded_object[k]['alpha'][0] for k in range(len(loaded_object))]
alpha1 = [loaded_object[k]['alpha'][1] for k in range(len(loaded_object))]
alpha2 = [loaded_object[k]['alpha'][2] for k in range(len(loaded_object))]
alpha3 = [loaded_object[k]['alpha'][3] for k in range(len(loaded_object))]
alpha4 = [loaded_object[k]['alpha'][4] for k in range(len(loaded_object))]
alpha5 = [loaded_object[k]['alpha'][5] for k in range(len(loaded_object))]

# %%
plt.plot(kl,alpha0)
plt.plot(kl,alpha1)
plt.plot(kl,alpha2)
plt.plot(kl,alpha3)
plt.plot(kl,alpha4)
plt.plot(kl,alpha5)
